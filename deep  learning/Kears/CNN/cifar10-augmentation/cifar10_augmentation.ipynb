# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)

# %% [markdown]
# Modify Step 5: Create and Configure Augmented Image Generator in the notebook to use different settings for data augmentation. You can peruse the list of available arguments here.

# %%
from keras.preprocessing.image import ImageDataGenerator

gen_test=ImageDataGenerator(
        #samplewise_center=True,
        #featurewise_std_normalization=True,
        rotation_range=45,
        width_shift_range=.5,
        height_shift_range=.7,
        zoom_range=.1,
        channel_shift_range=.1,
        horizontal_flip=True,
        vertical_flip=True)

gen_test.fit(x_train)

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in gen_test.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %%
# train data
from keras.callbacks import ModelCheckpoint
pointer=ModelCheckpoint(filepath='test.model',
                       verbose=1,save_best_only=True)
batch_size=32
model.fit_generator(gen_test.flow(x_train,y_train,batch_size=batch_size),
                   steps_per_epoch=x_train.shape[0]/batch_size,
                   epochs=100,verbose=1,validation_data=(x_valid,y_valid),
                    callbacks=[pointer],
                   validation_steps=x_valid.shape[0] // batch_size)
# Out:
# Epoch 1/100
# 1406/1406 [============================>.] - ETA: 0s - loss: 2.1239 - acc: 0.2077Epoch 00001: val_loss improved from inf to 1.85564, saving model to test.model
# 1407/1406 [==============================] - 30s 21ms/step - loss: 2.1238 - acc: 0.2078 - val_loss: 1.8556 - val_acc: 0.3282
# Epoch 2/100
# 1406/1406 [============================>.] - ETA: 0s - loss: 2.0217 - acc: 0.2526Epoch 00002: val_loss improved from 1.85564 to 1.84180, saving model to test.model
# 1407/1406 [==============================] - 29s 21ms/step - loss: 2.0218 - acc: 0.2526 - val_loss: 1.8418 - val_acc: 0.3062
# Epoch 3/100
# 1404/1406 [============================>.] - ETA: 0s - loss: 1.9867 - acc: 0.2691Epoch 00003: val_loss improved from 1.84180 to 1.73794, saving model to test.model
# 1407/1406 [==============================] - 29s 20ms/step - loss: 1.9867 - acc: 0.2690 - val_loss: 1.7379 - val_acc: 0.3720
# Epoch 4/100
# 1405/1406 [============================>.] - ETA: 0s - loss: 1.9649 - acc: 0.2818Epoch 00004: val_loss improved from 1.73794 to 1.68703, saving model to test.model
# 1407/1406 [==============================] - 29s 20ms/step - loss: 1.9650 - acc: 0.2818 - val_loss: 1.6870 - val_acc: 0.3784
# Epoch 5/100
# 1406/1406 [============================>.] - ETA: 0s - loss: 1.9424 - acc: 0.2926Epoch 00005: val_loss did not improve
# 1407/1406 [==============================] - 29s 20ms/step - loss: 1.9423 - acc: 0.2927 - val_loss: 1.7495 - val_acc: 0.3636
# Epoch 6/100
# 1404/1406 [============================>.] - ETA: 0s - loss: 1.9363 - acc: 0.2920Epoch 00006: val_loss improved from 1.68703 to 1.64651, saving model to test.model
# 1407/1406 [==============================] - 29s 20ms/step - loss: 1.9364 - acc: 0.2917 - val_loss: 1.6465 - val_acc: 0.4124
# Epoch 7/100
# 1406/1406 [============================>.] - ETA: 0s - loss:
val_loss did not improve
# 1407/1406 [==============================] - 29s 21ms/step - loss: 2.0723 - acc: 0.2365 - val_loss: 1.8950 - val_acc: 0.2472
# Epoch 95/100
# 1406/1406 [============================>.] - ETA: 0s - loss: 2.0819 - acc: 0.2280Epoch 00095: val_loss did not improve
# 1407/1406 [==============================] - 29s 21ms/step - loss: 2.0818 - acc: 0.2281 - val_loss: 1.9093 - val_acc: 0.2870
# Epoch 96/100
# 1404/1406 [============================>.] - ETA: 0s - loss: 2.0827 - acc: 0.2301Epoch 00096: val_loss did not improve
# 1407/1406 [==============================] - 29s 21ms/step - loss: 2.0826 - acc: 0.2302 - val_loss: 1.9044 - val_acc: 0.2946
# Epoch 97/100
# 1406/1406 [============================>.] - ETA: 0s - loss: 2.0830 - acc: 0.2301Epoch 00097: val_loss did not improve
# 1407/1406 [==============================] - 29s 21ms/step - loss: 2.0828 - acc: 0.2301 - val_loss: 1.9122 - val_acc: 0.2894
# Epoch 98/100
# 1406/1406 [============================>.] - ETA: 0s - loss: 2.0880 - acc: 0.2273Epoch 00098: val_loss did not improve
# 1407/1406 [==============================] - 29s 20ms/step - loss: 2.0880 - acc: 0.2273 - val_loss: 1.8839 - val_acc: 0.3070
# Epoch 99/100
# 1405/1406 [============================>.] - ETA: 0s - loss: 2.0945 - acc: 0.2274Epoch 00099: val_loss did not improve
# 1407/1406 [==============================] - 29s 21ms/step - loss: 2.0945 - acc: 0.2273 - val_loss: 1.8831 - val_acc: 0.3078
# Epoch 100/100
# 1406/1406 [============================>.] - ETA: 0s - loss: 2.0866 - acc: 0.2282Epoch 00100: val_loss did not improve
# 1407/1406 [==============================] - 29s 20ms/step - loss: 2.0867 - acc: 0.2282 - val_loss: 1.9507 - val_acc: 0.2952

# %%
score_test=model.evaluate(x_test,y_test)
score_test[1]
# Out:
# 10000/10000 [==============================] - 1s 116us/step
# 0.30270000000000002

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\victo\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=(x_valid, y_valid),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# Epoch 1/100
# Epoch 00001: val_loss improved from inf to 1.34030, saving model to aug_model.weights.best.hdf5
#  - 25s - loss: 1.6731 - acc: 0.3926 - val_loss: 1.3403 - val_acc: 0.5200
# Epoch 2/100
# Epoch 00002: val_loss improved from 1.34030 to 1.20360, saving model to aug_model.weights.best.hdf5
#  - 26s - loss: 1.4098 - acc: 0.4913 - val_loss: 1.2036 - val_acc: 0.5744
# Epoch 3/100
# Epoch 00003: val_loss improved from 1.20360 to 1.06835, saving model to aug_model.weights.best.hdf5
#  - 26s - loss: 1.2899 - acc: 0.5387 - val_loss: 1.0684 - val_acc: 0.6196
# Epoch 4/100
# Epoch 00004: val_loss improved from 1.06835 to 1.05189, saving model to aug_model.weights.best.hdf5
#  - 28s - loss: 1.2218 - acc: 0.5654 - val_loss: 1.0519 - val_acc: 0.6384
# Epoch 5/100
# Epoch 00005: val_loss improved from 1.05189 to 1.00184, saving model to aug_model.weights.best.hdf5
#  - 27s - loss: 1.1828 - acc: 0.5815 - val_loss: 1.0018 - val_acc: 0.6464
# Epoch 6/100
# Epoch 00006: val_loss improved from 1.00184 to 0.99436, saving model to aug_model.weights.best.hdf5
#  - 27s - loss: 1.1514 - acc: 0.5944 - val_loss: 0.9944 - val_acc: 0.6568
# Epoch 7/100
# Epoch 00007: val_loss did not improve
#  - 28s - loss: 1.1345 - acc: 0.6045 - val_loss: 1.0388 - val_acc: 0.6400
# Epoch 8/100
# Epoch 00008: val_loss improved from 0.99436 to 0.93801, saving model to aug_model.weights.best.hdf5
#  - 27s - loss: 1.1327 - acc: 0.6076 - val_loss: 0.9380 - val_acc: 0.6808
# Epoch 9/100
# Epoch 00009: val_loss improved from 0.93801 to 0.90033, saving model to aug_model.weights.best.hdf5
#  - 27s - loss: 1.1231 - acc: 0.6131 - val_loss: 0.9003 - val_acc: 0.6934
# Epoch 10/100
# Epoch 00010: val_loss did not improve
#  - 30s - loss: 1.1277 - acc: 0.6128 - val_loss: 0.9446 - val_acc: 0.6770
# Epoch 11/100
# Epoch 00011: val_loss did not improve
#  - 28s - loss: 1.1461 - acc: 0.6098 - val_loss: 0.9625 - val_acc: 0.6762
# Epoch 12/100
# Epoch 00012: val_loss did not improve
#  - 28s - loss: 1.1533 - acc: 0.6098 - val_loss: 0.9983 - val_acc: 0.6692
# Epoch 13/100
# Epoch 00013: val_loss did not improve
#  - 27s - loss: 1.1561 - acc: 0.6059 - val_loss: 0.9408 - val_acc: 0.6774
# Epoch 14/100
# Epoch 00014: val_loss did not improve
#  - 27s - loss: 1.1725 - acc: 0.6016 - val_loss: 1.1489 - val_acc: 0.6192
# Epoch 15/100
# Epoch 00015: val_loss did not improve
#  - 27s - loss: 1.1833 - acc: 0.5946 - val_loss: 0.9671 - val_acc: 0.6714
# Epoch 16/100
# Epoch 00016: val_loss did not improve
#  - 27s - loss: 1.1927 - acc: 0.5981 - val_loss: 0.9901 - val_acc: 0.6692
# Epoch 17/100
# Epoch 00017: val_loss did not improve
#  - 26s - loss: 1.2065 - acc: 0.5916 - val_loss: 1.0781 - val_acc: 0.6496
# Epoch 18/100
# Epoch 00018: val_loss did not improve
#  - 26s - loss: 1.2116 - acc: 0.5895 - val_loss: 0.9402 - val_acc: 0.6884
# Epoch 19/100
# Epoch 00019: val_loss did not improve
#  - 27s - loss: 1.2393 - acc: 0.5791 - val_loss: 0.9724 - val_acc: 0.6672
# Epoch 20/100
# Epoch 00020: val_loss did not improve
#  - 27s - loss: 1.2446 - acc: 0.5838 - val_loss: 1.1988 - val_acc: 0.6176
# Epoch 21/100
# Epoch 00021: val_loss did not improve
#  - 27s - loss: 1.2549 - acc: 0.5782 - val_loss: 1.0379 - val_acc: 0.6564
# Epoch 22/100
# Epoch 00022: val_loss did not improve
#  - 27s - loss: 1.2712 - acc: 0.5742 - val_loss: 1.0458 - val_acc: 0.6384
# Epoch 23/100
# Epoch 00023: val_loss did not improve
#  - 27s - loss: 1.2822 - acc: 0.5671 - val_loss: 1.1159 - val_acc: 0.6260
# Epoch 24/100
# Epoch 00024: val_loss did not improve
#  - 27s - loss: 1.3032 - acc: 0.5621 - val_loss: 1.0199 - val_acc: 0.6614
# Epoch 25/100
# Epoch 00025: val_loss did not improve
#  - 28s - loss: 1.3113 - acc: 0.5572 - val_loss: 1.0287 - val_acc: 0.6480
# Epoch 26/100
# Epoch 00026: val_loss did not improve
#  - 27s - loss: 1.3256 - acc: 0.5527 - val_loss: 1.1103 - val_acc: 0.6342
# Epoch 27/100
# Epoch 00027: val_loss did not improve
#  - 27s - loss: 1.3389 - acc: 0.5531 - val_loss: 1.1076 - val_acc: 0.6260
# Epoch 28/100
# Epoch 00028: val_loss did not improve
#  - 27s - loss: 1.3552 - acc: 0.5463 - val_loss: 1.2018 - val_acc: 0.6074
# Epoch 29/100
# Epoch 00029: val_loss did not improve
#  - 27s - loss: 1.3726 - acc: 0.5401 - val_loss: 1.0704 - val_acc: 0.6298
# Epoch 30/100
# Epoch 00030: val_loss did not improve
#  - 26s - loss: 1.3793 - acc: 0.5365 - val_loss: 1.1123 - val_acc: 0.6368
# Epoch 31/100
# Epoch 00031: val_loss did not improve
#  - 27s - loss: 1.3821 - acc: 0.5359 - val_loss: 1.1223 - val_acc: 0.6020
# Epoch 32/100
# Epoch 00032: val_loss did not improve
#  - 26s - loss: 1.4084 - acc: 0.5263 - val_loss: 1.0304 - val_acc: 0.6550
# Epoch 33/100
# Epoch 00033: val_loss did not improve
#  - 27s - loss: 1.4002 - acc: 0.5254 - val_loss: 1.2006 - val_acc: 0.5980
# Epoch 34/100
# Epoch 00034: val_loss did not improve
#  - 29s - loss: 1.4007 - acc: 0.5275 - val_loss: 1.1343 - val_acc: 0.6080
# Epoch 35/100
# Epoch 00035: val_loss did not improve
#  - 30s - loss: 1.4313 - acc: 0.5190 - val_loss: 1.3779 - val_acc: 0.5134
# Epoch 36/100
# Epoch 00036: val_loss did not improve
#  - 29s - loss: 1.4358 - acc: 0.5147 - val_loss: 1.0703 - val_acc: 0.6246
# Epoch 37/100
# Epoch 00037: val_loss did not improve
#  - 28s - loss: 1.4557 - acc: 0.5076 - val_loss: 1.2513 - val_acc: 0.5658
# Epoch 38/100
# Epoch 00038: val_loss did not improve
#  - 28s - loss: 1.4660 - acc: 0.5055 - val_loss: 1.2756 - val_acc: 0.5718
# Epoch 39/100
# Epoch 00039: val_loss did not improve
#  - 28s - loss: 1.4817 - acc: 0.5036 - val_loss: 1.2498 - val_acc: 0.5686
# Epoch 40/100
# Epoch 00040: val_loss did not improve
#  - 28s - loss: 1.4733 - acc: 0.5026 - val_loss: 1.2476 - val_acc: 0.5880
# Epoch 41/100
# Epoch 00041: val_loss did not improve
#  - 29s - loss: 1.5009 - acc: 0.4944 - val_loss: 1.2205 - val_acc: 0.5800
# Epoch 42/100
# Epoch 00042: val_loss did not improve
#  - 31s - loss: 1.5077 - acc: 0.4878 - val_loss: 1.3240 - val_acc: 0.5290
# Epoch 43/100
# Epoch 00043: val_loss did not improve
#  - 29s - loss: 1.5362 - acc: 0.4837 - val_loss: 1.1579 - val_acc: 0.6122
# Epoch 44/100
# Epoch 00044: val_loss did not improve
#  - 30s - loss: 1.5341 - acc: 0.4871 - val_loss: 2.1235 - val_acc: 0.4534
# Epoch 45/100
# Epoch 00045: val_loss did not improve
#  - 30s - loss: 1.5470 - acc: 0.4790 - val_loss: 1.4426 - val_acc: 0.5370
# Epoch 46/100
# Epoch 00046: val_loss did not improve
#  - 30s - loss: 1.5529 - acc: 0.4756 - val_loss: 1.3208 - val_acc: 0.5614
# Epoch 47/100
# Epoch 00047: val_loss did not improve
#  - 30s - loss: 1.5792 - acc: 0.4677 - val_loss: 1.3244 - val_acc: 0.5354
# Epoch 48/100
# Epoch 00048: val_loss did not improve
#  - 30s - loss: 1.6049 - acc: 0.4598 - val_loss: 1.3668 - val_acc: 0.5046
# Epoch 49/100
# Epoch 00049: val_loss did not improve
#  - 30s - loss: 1.6112 - acc: 0.4544 - val_loss: 1.2489 - val_acc: 0.5798
# Epoch 50/100
# Epoch 00050: val_loss did not improve
#  - 29s - loss: 1.6110 - acc: 0.4562 - val_loss: 1.4660 - val_acc: 0.5098
# Epoch 51/100
# Epoch 00051: val_loss did not improve
#  - 29s - loss: 1.6227 - acc: 0.4461 - val_loss: 1.4369 - val_acc: 0.4752
# Epoch 52/100
# Epoch 00052: val_loss did not improve
#  - 31s - loss: 1.6286 - acc: 0.4462 - val_loss: 1.2512 - val_acc: 0.5728
# Epoch 53/100
# Epoch 00053: val_loss did not improve
#  - 29s - loss: 1.6356 - acc: 0.4403 - val_loss: 1.6888 - val_acc: 0.4152
# Epoch 54/100
# Epoch 00054: val_loss did not improve
#  - 30s - loss: 1.6470 - acc: 0.4359 - val_loss: 1.4789 - val_acc: 0.4778
# Epoch 55/100
# Epoch 00055: val_loss did not improve
#  - 31s - loss: 1.6398 - acc: 0.4412 - val_loss: 1.4163 - val_acc: 0.4696
# Epoch 56/100
# Epoch 00056: val_loss did not improve
#  - 29s - loss: 1.6572 - acc: 0.4315 - val_loss: 1.4186 - val_acc: 0.4986
# Epoch 57/100
# Epoch 00057: val_loss did not improve
#  - 28s - loss: 1.6670 - acc: 0.4275 - val_loss: 1.4326 - val_acc: 0.5154
# Epoch 58/100
# Epoch 00058: val_loss did not improve
#  - 27s - loss: 1.6707 - acc: 0.4217 - val_loss: 1.5090 - val_acc: 0.4608
# Epoch 59/100
# Epoch 00059: val_loss did not improve
#  - 27s - loss: 1.6649 - acc: 0.4255 - val_loss: 1.3305 - val_acc: 0.5416
# Epoch 60/100

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6833
